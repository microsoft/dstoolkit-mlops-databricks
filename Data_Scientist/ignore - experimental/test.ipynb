# %%
# %pip install azureml-mlflow
# %pip install azureml-core
# %pip install azure-ai-ml
# Out:
# Python interpreter will be restarted.
# Requirement already satisfied: azureml-mlflow in /local_disk0/.ephemeral_nfs/envs/pythonEnv-9c30680a-7243-44a5-b665-d717c452c9ec/lib/python3.9/site-packages (1.49.0)
# Requirement already satisfied: jsonpickle in /local_disk0/.ephemeral_nfs/envs/pythonEnv-9c30680a-7243-44a5-b665-d717c452c9ec/lib/python3.9/site-packages (from azureml-mlflow) (2.2.0)
# Requirement already satisfied: msrest>=0.6.18 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-9c30680a-7243-44a5-b665-d717c452c9ec/lib/python3.9/site-packages (from azureml-mlflow) (0.7.1)
# Requirement already satisfied: azure-mgmt-core<2.0.0,>=1.2.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-9c30680a-7243-44a5-b665-d717c452c9ec/lib/python3.9/site-packages (from azureml-mlflow) (1.3.2)
# Requirement already satisfied: cryptography in /local_disk0/.ephemeral_nfs/envs/pythonEnv-9c30680a-7243-44a5-b665-d717c452c9ec/lib/python3.9/site-packages (from azureml-mlflow) (39.0.2)
# Requirement already satisfied: azure-common<2.0.0,>=1.1 in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.9/site-packages (from azureml-mlflow) (1.1.28)
# Requirement already satisfied: mlflow-skinny in /databricks/python3/lib/python3.9/site-packages (from azureml-mlflow) (1.29.0)
# Requirement already satisfied: azure-core!=1.22.0,<2.0.0,>=1.8.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-9c30680a-7243-44a5-b665-d717c452c9ec/lib/python3.9/site-packages (from azureml-mlflow) (1.26.3)
# Collecting azure-storage-blob<=12.13.0,>=12.5.0
#   Using cached azure_storage_blob-12.13.0-py3-none-any.whl (377 kB)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.7.3 in /databricks/python3/lib/python3.9/site-packages (from azureml-mlflow) (2.8.2)
# Requirement already satisfied: azure-identity in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.9/site-packages (from azureml-mlflow) (1.12.0)
# Requirement already satisfied: six>=1.11.0 in /databricks/python3/lib/python3.9/site-packages (from azure-core!=1.22.0,<2.0.0,>=1.8.0->azureml-mlflow) (1.16.0)
# Requirement already satisfied: requests>=2.18.4 in /databricks/python3/lib/python3.9/site-packages (from azure-core!=1.22.0,<2.0.0,>=1.8.0->azureml-mlflow) (2.26.0)
# Requirement already satisfied: typing-extensions>=4.0.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-9c30680a-7243-44a5-b665-d717c452c9ec/lib/python3.9/site-packages (from azure-core!=1.22.0,<2.0.0,>=1.8.0->azureml-mlflow) (4.5.0)
# Requirement already satisfied: cffi>=1.12 in /databricks/python3/lib/python3.9/site-packages (from cryptography->azureml-mlflow) (1.14.6)
# Requirement already satisfied: pycparser in /databricks/python3/lib/python3.9/site-packages (from cffi>=1.12->cryptography->azureml-mlflow) (2.20)
# Requirement already satisfied: isodate>=0.6.0 in /databricks/python3/lib/python3.9/site-packages (from msrest>=0.6.18->azureml-mlflow) (0.6.1)
# Requirement already satisfied: requests-oauthlib>=0.5.0 in /databricks/python3/lib/python3.9/site-packages (from msrest>=0.6.18->azureml-mlflow) (1.3.1)
# Requirement already satisfied: certifi>=2017.4.17 in /databricks/python3/lib/python3.9/site-packages (from msrest>=0.6.18->azureml-mlflow) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in /databricks/python3/lib/python3.9/site-packages (from requests>=2.18.4->azure-core!=1.22.0,<2.0.0,>=1.8.0->azureml-mlflow) (3.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /databricks/python3/lib/python3.9/site-packages (from requests>=2.18.4->azure-core!=1.22.0,<2.0.0,>=1.8.0->azureml-mlflow) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /databricks/python3/lib/python3.9/site-packages (from requests>=2.18.4->azure-core!=1.22.0,<2.0.0,>=1.8.0->azureml-mlflow) (1.26.7)
# Requirement already satisfied: oauthlib>=3.0.0 in /databricks/python3/lib/python3.9/site-packages (from requests-oauthlib>=0.5.0->msrest>=0.6.18->azureml-mlflow) (3.2.0)
# Requirement already satisfied: msal-extensions<2.0.0,>=0.3.0 in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.9/site-packages (from azure-identity->azureml-mlflow) (1.0.0)
# Requirement already satisfied: msal<2.0.0,>=1.12.0 in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.9/site-packages (from azure-identity->azureml-mlflow) (1.21.0)
# Requirement already satisfied: PyJWT[crypto]<3,>=1.0.0 in /databricks/python3/lib/python3.9/site-packages (from msal<2.0.0,>=1.12.0->azure-identity->azureml-mlflow) (2.5.0)
# Requirement already satisfied: portalocker<3,>=1.0 in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.9/site-packages (from msal-extensions<2.0.0,>=0.3.0->azure-identity->azureml-mlflow) (2.7.0)
# Requirement already satisfied: types-cryptography>=3.3.21 in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.9/site-packages (from PyJWT[crypto]<3,>=1.0.0->msal<2.0.0,>=1.12.0->azure-identity->azureml-mlflow) (3.3.23.2)
# Requirement already satisfied: gitpython<4,>=2.1.0 in /databricks/python3/lib/python3.9/site-packages (from mlflow-skinny->azureml-mlflow) (3.1.27)
# Requirement already satisfied: cloudpickle<3 in /databricks/python3/lib/python3.9/site-packages (from mlflow-skinny->azureml-mlflow) (2.0.0)
# Requirement already satisfied: protobuf<5,>=3.12.0 in /databricks/python3/lib/python3.9/site-packages (from mlflow-skinny->azureml-mlflow) (3.19.4)
# Requirement already satisfied: pyyaml<7,>=5.1 in /databricks/python3/lib/python3.9/site-packages (from mlflow-skinny->azureml-mlflow) (6.0)
# Requirement already satisfied: pytz<2023 in /databricks/python3/lib/python3.9/site-packages (from mlflow-skinny->azureml-mlflow) (2021.3)
# Requirement already satisfied: entrypoints<1 in /databricks/python3/lib/python3.9/site-packages (from mlflow-skinny->azureml-mlflow) (0.3)
# Requirement already satisfied: importlib-metadata!=4.7.0,<5,>=3.7.0 in /databricks/python3/lib/python3.9/site-packages (from mlflow-skinny->azureml-mlflow) (4.8.1)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in /databricks/python3/lib/python3.9/site-packages (from mlflow-skinny->azureml-mlflow) (0.4.2)
# Requirement already satisfied: databricks-cli<1,>=0.8.7 in /databricks/python3/lib/python3.9/site-packages (from mlflow-skinny->azureml-mlflow) (0.17.3)
# Requirement already satisfied: packaging<22 in /databricks/python3/lib/python3.9/site-packages (from mlflow-skinny->azureml-mlflow) (21.0)
# Requirement already satisfied: click<9,>=7.0 in /databricks/python3/lib/python3.9/site-packages (from mlflow-skinny->azureml-mlflow) (8.0.3)
# Requirement already satisfied: tabulate>=0.7.7 in /databricks/python3/lib/python3.9/site-packages (from databricks-cli<1,>=0.8.7->mlflow-skinny->azureml-mlflow) (0.8.9)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /databricks/python3/lib/python3.9/site-packages (from gitpython<4,>=2.1.0->mlflow-skinny->azureml-mlflow) (4.0.9)
# Requirement already satisfied: smmap<6,>=3.0.1 in /databricks/python3/lib/python3.9/site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=2.1.0->mlflow-skinny->azureml-mlflow) (5.0.0)
# Requirement already satisfied: zipp>=0.5 in /databricks/python3/lib/python3.9/site-packages (from importlib-metadata!=4.7.0,<5,>=3.7.0->mlflow-skinny->azureml-mlflow) (3.6.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /databricks/python3/lib/python3.9/site-packages (from packaging<22->mlflow-skinny->azureml-mlflow) (3.0.4)
# Installing collected packages: azure-storage-blob
#   Attempting uninstall: azure-storage-blob
#     Found existing installation: azure-storage-blob 12.15.0
#     Uninstalling azure-storage-blob-12.15.0:
#       Successfully uninstalled azure-storage-blob-12.15.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# azure-storage-file-datalake 12.10.1 requires azure-storage-blob<13.0.0,>=12.15.0, but you have azure-storage-blob 12.13.0 which is incompatible.
# Successfully installed azure-storage-blob-12.13.0
# Python interpreter will be restarted.
# Python interpreter will be restarted.
# Requirement already satisfied: azureml-core in /local_disk0/.ephemeral_nfs/envs/pythonEnv-9c30680a-7243-44a5-b665-d717c452c9ec/lib/python3.9/site-packages (1.49.0)
# Requirement already satisfied: azure-mgmt-storage<21.0.0,>=16.0.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-9c30680a-7243-44a5-b665-d717c452c9ec/lib/python3.9/site-packages (from azureml-core) (20.1.0)
# Requirement already satisfied: adal<=1.2.7,>=1.2.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-9c30680a-7243-44a5-b665-d717c452c9ec/lib/python3.9/site-packages (from azureml-core) (1.2.7)
# Requirement already satisfied: azure-mgmt-containerregistry<11,>=8.2.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-9c30680a-7243-44a5-b665-d717c452c9ec/lib/python3.9/site-packages (from azureml-core) (10.1.0)
# Requirement already satisfied: argcomplete<3 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-9c30680a-7243-44a5-b665-d717c452c9ec/lib/python3.9/site-packages (from azureml-core) (2.1.1)
# Requirement already satisfied: docker<7.0.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-9c30680a-7243-44a5-b665-d717c452c9ec/lib/python3.9/site-packages (from azureml-core) (6.0.1)
# Requirement already satisfied: jmespath<2.0.0 in /databricks/python3/lib/python3.9/site-packages (from azureml-core) (0.10.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.7.3 in /databricks/python3/lib/python3.9/site-packages (from azureml-core) (2.8.2)
# Requirement already satisfied: azure-mgmt-resource<22.0.0,>=15.0.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-9c30680a-7243-44a5-b665-d717c452c9ec/lib/python3.9/site-packages (from azureml-core) (21.2.1)
# Requirement already satisfied: msal<2.0.0,>=1.15.0 in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.9/site-packages (from azureml-core) (1.21.0)
# Requirement already satisfied: ndg-httpsclient<=0.5.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-9c30680a-7243-44a5-b665-d717c452c9ec/lib/python3.9/site-packages (from azureml-core) (0.5.1)
# Requirement already satisfied: requests[socks]<3.0.0,>=2.19.1 in /databricks/python3/lib/python3.9/site-packages (from azureml-core) (2.26.0)
# Requirement already satisfied: azure-core<2.0.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-9c30680a-7243-44a5-b665-d717c452c9ec/lib/python3.9/site-packages (from azureml-core) (1.26.3)
# Requirement already satisfied: pyopenssl<24.0.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-9c30680a-7243-44a5-b665-d717c452c9ec/lib/python3.9/site-packages (from azureml-core) (23.0.0)
# Requirement already satisfied: azure-mgmt-authorization<4,>=0.40.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-9c30680a-7243-44a5-b665-d717c452c9ec/lib/python3.9/site-packages (from azureml-core) (3.0.0)
# Requirement already satisfied: knack~=0.10.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-9c30680a-7243-44a5-b665-d717c452c9ec/lib/python3.9/site-packages (from azureml-core) (0.10.1)
# Requirement already satisfied: pathspec<1.0.0 in /databricks/python3/lib/python3.9/site-packages (from azureml-core) (0.9.0)
# Requirement already satisfied: azure-mgmt-keyvault<11.0.0,>=0.40.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-9c30680a-7243-44a5-b665-d717c452c9ec/lib/python3.9/site-packages (from azureml-core) (10.1.0)
# Requirement already satisfied: pkginfo in /local_disk0/.ephemeral_nfs/envs/pythonEnv-9c30680a-7243-44a5-b665-d717c452c9ec/lib/python3.9/site-packages (from azureml-core) (1.9.6)
# Requirement already satisfied: msrest<=0.7.1,>=0.5.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-9c30680a-7243-44a5-b665-d717c452c9ec/lib/python3.9/site-packages (from azureml-core) (0.7.1)
# Requirement already satisfied: msrestazure<=0.6.4,>=0.4.33 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-9c30680a-7243-44a5-b665-d717c452c9ec/lib/python3.9/site-packages (from azureml-core) (0.6.4)
# Requirement already satisfied: msal-extensions<=1.0.0,>=0.3.0 in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.9/site-packages (from azureml-core) (1.0.0)
# Requirement already satisfied: pytz in /databricks/python3/lib/python3.9/site-packages (from azureml-core) (2021.3)
# Requirement already satisfied: packaging<22.0,>=20.0 in /databricks/python3/lib/python3.9/site-packages (from azureml-core) (21.0)
# Requirement already satisfied: paramiko<3.0.0,>=2.0.8 in /databricks/python3/lib/python3.9/site-packages (from azureml-core) (2.9.2)
# Requirement already satisfied: SecretStorage<4.0.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-9c30680a-7243-44a5-b665-d717c452c9ec/lib/python3.9/site-packages (from azureml-core) (3.3.3)
# Requirement already satisfied: PyJWT<3.0.0 in /databricks/python3/lib/python3.9/site-packages (from azureml-core) (2.5.0)
# Requirement already satisfied: jsonpickle<3.0.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-9c30680a-7243-44a5-b665-d717c452c9ec/lib/python3.9/site-packages (from azureml-core) (2.2.0)
# Requirement already satisfied: cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*,<41 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-9c30680a-7243-44a5-b665-d717c452c9ec/lib/python3.9/site-packages (from azureml-core) (39.0.2)
# Requirement already satisfied: azure-common<2.0.0,>=1.1.12 in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.9/site-packages (from azureml-core) (1.1.28)
# Requirement already satisfied: humanfriendly<11.0,>=4.7 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-9c30680a-7243-44a5-b665-d717c452c9ec/lib/python3.9/site-packages (from azureml-core) (10.0)
# Requirement already satisfied: azure-graphrbac<1.0.0,>=0.40.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-9c30680a-7243-44a5-b665-d717c452c9ec/lib/python3.9/site-packages (from azureml-core) (0.61.1)
# Requirement already satisfied: backports.tempfile in /local_disk0/.ephemeral_nfs/envs/pythonEnv-9c30680a-7243-44a5-b665-d717c452c9ec/lib/python3.9/site-packages (from azureml-core) (1.0)
# Requirement already satisfied: urllib3<2.0.0,>=1.23 in /databricks/python3/lib/python3.9/site-packages (from azureml-core) (1.26.7)
# Requirement already satisfied: contextlib2<22.0.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-9c30680a-7243-44a5-b665-d717c452c9ec/lib/python3.9/site-packages (from azureml-core) (21.6.0)
# Requirement already satisfied: six>=1.11.0 in /databricks/python3/lib/python3.9/site-packages (from azure-core<2.0.0->azureml-core) (1.16.0)
# Requirement already satisfied: typing-extensions>=4.0.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-9c30680a-7243-44a5-b665-d717c452c9ec/lib/python3.9/site-packages (from azure-core<2.0.0->azureml-core) (4.5.0)
# Requirement already satisfied: azure-mgmt-core<2.0.0,>=1.3.2 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-9c30680a-7243-44a5-b665-d717c452c9ec/lib/python3.9/site-packages (from azure-mgmt-authorization<4,>=0.40.0->azureml-core) (1.3.2)
# Requirement already satisfied: cffi>=1.12 in /databricks/python3/lib/python3.9/site-packages (from cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*,<41->azureml-core) (1.14.6)
# Requirement already satisfied: pycparser in /databricks/python3/lib/python3.9/site-packages (from cffi>=1.12->cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*,<41->azureml-core) (2.20)
# Requirement already satisfied: websocket-client>=0.32.0 in /databricks/python3/lib/python3.9/site-packages (from docker<7.0.0->azureml-core) (1.3.1)
# Requirement already satisfied: pygments in /databricks/python3/lib/python3.9/site-packages (from knack~=0.10.0->azureml-core) (2.10.0)
# Requirement already satisfied: tabulate in /databricks/python3/lib/python3.9/site-packages (from knack~=0.10.0->azureml-core) (0.8.9)
# Requirement already satisfied: pyyaml in /databricks/python3/lib/python3.9/site-packages (from knack~=0.10.0->azureml-core) (6.0)
# Requirement already satisfied: portalocker<3,>=1.0 in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.9/site-packages (from msal-extensions<=1.0.0,>=0.3.0->azureml-core) (2.7.0)
# Requirement already satisfied: isodate>=0.6.0 in /databricks/python3/lib/python3.9/site-packages (from msrest<=0.7.1,>=0.5.1->azureml-core) (0.6.1)
# Requirement already satisfied: requests-oauthlib>=0.5.0 in /databricks/python3/lib/python3.9/site-packages (from msrest<=0.7.1,>=0.5.1->azureml-core) (1.3.1)
# Requirement already satisfied: certifi>=2017.4.17 in /databricks/python3/lib/python3.9/site-packages (from msrest<=0.7.1,>=0.5.1->azureml-core) (2021.10.8)
# Requirement already satisfied: pyasn1>=0.1.1 in /databricks/python3/lib/python3.9/site-packages (from ndg-httpsclient<=0.5.1->azureml-core) (0.4.8)
# Requirement already satisfied: pyparsing>=2.0.2 in /databricks/python3/lib/python3.9/site-packages (from packaging<22.0,>=20.0->azureml-core) (3.0.4)
# Requirement already satisfied: bcrypt>=3.1.3 in /databricks/python3/lib/python3.9/site-packages (from paramiko<3.0.0,>=2.0.8->azureml-core) (4.0.0)
# Requirement already satisfied: pynacl>=1.0.1 in /databricks/python3/lib/python3.9/site-packages (from paramiko<3.0.0,>=2.0.8->azureml-core) (1.5.0)
# Requirement already satisfied: types-cryptography>=3.3.21 in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.9/site-packages (from PyJWT<3.0.0->azureml-core) (3.3.23.2)
# Requirement already satisfied: idna<4,>=2.5 in /databricks/python3/lib/python3.9/site-packages (from requests[socks]<3.0.0,>=2.19.1->azureml-core) (3.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /databricks/python3/lib/python3.9/site-packages (from requests[socks]<3.0.0,>=2.19.1->azureml-core) (2.0.4)
# Requirement already satisfied: oauthlib>=3.0.0 in /databricks/python3/lib/python3.9/site-packages (from requests-oauthlib>=0.5.0->msrest<=0.7.1,>=0.5.1->azureml-core) (3.2.0)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-9c30680a-7243-44a5-b665-d717c452c9ec/lib/python3.9/site-packages (from requests[socks]<3.0.0,>=2.19.1->azureml-core) (1.7.1)
# Requirement already satisfied: jeepney>=0.6 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-9c30680a-7243-44a5-b665-d717c452c9ec/lib/python3.9/site-packages (from SecretStorage<4.0.0->azureml-core) (0.8.0)
# Requirement already satisfied: backports.weakref in /local_disk0/.ephemeral_nfs/envs/pythonEnv-9c30680a-7243-44a5-b665-d717c452c9ec/lib/python3.9/site-packages (from backports.tempfile->azureml-core) (1.0.post1)
# Python interpreter will be restarted.
# Python interpreter will be restarted.
# Requirement already satisfied: azure-ai-ml in /local_disk0/.ephemeral_nfs/envs/pythonEnv-9c30680a-7243-44a5-b665-d717c452c9ec/lib/python3.9/site-packages (1.4.0)
# Requirement already satisfied: pyjwt<3.0.0 in /databricks/python3/lib/python3.9/site-packages (from azure-ai-ml) (2.5.0)
# Requirement already satisfied: typing-extensions<5.0.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-9c30680a-7243-44a5-b665-d717c452c9ec/lib/python3.9/site-packages (from azure-ai-ml) (4.5.0)
# Requirement already satisfied: tqdm<5.0.0 in /databricks/python3/lib/python3.9/site-packages (from azure-ai-ml) (4.62.3)
# Requirement already satisfied: jsonschema<5.0.0,>=4.0.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-9c30680a-7243-44a5-b665-d717c452c9ec/lib/python3.9/site-packages (from azure-ai-ml) (4.17.3)
# Requirement already satisfied: msrest>=0.6.18 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-9c30680a-7243-44a5-b665-d717c452c9ec/lib/python3.9/site-packages (from azure-ai-ml) (0.7.1)
# Requirement already satisfied: azure-storage-file-datalake<13.0.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-9c30680a-7243-44a5-b665-d717c452c9ec/lib/python3.9/site-packages (from azure-ai-ml) (12.10.1)
# Requirement already satisfied: azure-mgmt-core<2.0.0,>=1.3.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-9c30680a-7243-44a5-b665-d717c452c9ec/lib/python3.9/site-packages (from azure-ai-ml) (1.3.2)
# Requirement already satisfied: pydash<6.0.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-9c30680a-7243-44a5-b665-d717c452c9ec/lib/python3.9/site-packages (from azure-ai-ml) (5.1.2)
# Requirement already satisfied: azure-common<2.0.0,>=1.1 in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.9/site-packages (from azure-ai-ml) (1.1.28)
# Requirement already satisfied: pyyaml<7.0.0,>=5.1.0 in /databricks/python3/lib/python3.9/site-packages (from azure-ai-ml) (6.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.5 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-9c30680a-7243-44a5-b665-d717c452c9ec/lib/python3.9/site-packages (from azure-ai-ml) (3.19.0)
# Requirement already satisfied: strictyaml<2.0.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-9c30680a-7243-44a5-b665-d717c452c9ec/lib/python3.9/site-packages (from azure-ai-ml) (1.7.3)
# Requirement already satisfied: colorama<0.5.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-9c30680a-7243-44a5-b665-d717c452c9ec/lib/python3.9/site-packages (from azure-ai-ml) (0.4.6)
# Requirement already satisfied: azure-storage-file-share<13.0.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-9c30680a-7243-44a5-b665-d717c452c9ec/lib/python3.9/site-packages (from azure-ai-ml) (12.11.1)
# Requirement already satisfied: azure-storage-blob<13.0.0,>=12.10.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-9c30680a-7243-44a5-b665-d717c452c9ec/lib/python3.9/site-packages (from azure-ai-ml) (12.13.0)
# Requirement already satisfied: isodate in /databricks/python3/lib/python3.9/site-packages (from azure-ai-ml) (0.6.1)
# Requirement already satisfied: azure-core<2.0.0,>=1.23.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-9c30680a-7243-44a5-b665-d717c452c9ec/lib/python3.9/site-packages (from azure-ai-ml) (1.26.3)
# Requirement already satisfied: six>=1.11.0 in /databricks/python3/lib/python3.9/site-packages (from azure-core<2.0.0,>=1.23.0->azure-ai-ml) (1.16.0)
# Requirement already satisfied: requests>=2.18.4 in /databricks/python3/lib/python3.9/site-packages (from azure-core<2.0.0,>=1.23.0->azure-ai-ml) (2.26.0)
# Requirement already satisfied: cryptography>=2.1.4 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-9c30680a-7243-44a5-b665-d717c452c9ec/lib/python3.9/site-packages (from azure-storage-blob<13.0.0,>=12.10.0->azure-ai-ml) (39.0.2)
# Collecting azure-storage-blob<13.0.0,>=12.10.0
#   Using cached azure_storage_blob-12.15.0-py3-none-any.whl (387 kB)
# Requirement already satisfied: cffi>=1.12 in /databricks/python3/lib/python3.9/site-packages (from cryptography>=2.1.4->azure-storage-blob<13.0.0,>=12.10.0->azure-ai-ml) (1.14.6)
# Requirement already satisfied: pycparser in /databricks/python3/lib/python3.9/site-packages (from cffi>=1.12->cryptography>=2.1.4->azure-storage-blob<13.0.0,>=12.10.0->azure-ai-ml) (2.20)
# Requirement already satisfied: attrs>=17.4.0 in /databricks/python3/lib/python3.9/site-packages (from jsonschema<5.0.0,>=4.0.0->azure-ai-ml) (21.2.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /databricks/python3/lib/python3.9/site-packages (from jsonschema<5.0.0,>=4.0.0->azure-ai-ml) (0.18.0)
# Requirement already satisfied: packaging>=17.0 in /databricks/python3/lib/python3.9/site-packages (from marshmallow<4.0.0,>=3.5->azure-ai-ml) (21.0)
# Requirement already satisfied: requests-oauthlib>=0.5.0 in /databricks/python3/lib/python3.9/site-packages (from msrest>=0.6.18->azure-ai-ml) (1.3.1)
# Requirement already satisfied: certifi>=2017.4.17 in /databricks/python3/lib/python3.9/site-packages (from msrest>=0.6.18->azure-ai-ml) (2021.10.8)
# Requirement already satisfied: pyparsing>=2.0.2 in /databricks/python3/lib/python3.9/site-packages (from packaging>=17.0->marshmallow<4.0.0,>=3.5->azure-ai-ml) (3.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /databricks/python3/lib/python3.9/site-packages (from requests>=2.18.4->azure-core<2.0.0,>=1.23.0->azure-ai-ml) (3.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /databricks/python3/lib/python3.9/site-packages (from requests>=2.18.4->azure-core<2.0.0,>=1.23.0->azure-ai-ml) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /databricks/python3/lib/python3.9/site-packages (from requests>=2.18.4->azure-core<2.0.0,>=1.23.0->azure-ai-ml) (1.26.7)
# Requirement already satisfied: oauthlib>=3.0.0 in /databricks/python3/lib/python3.9/site-packages (from requests-oauthlib>=0.5.0->msrest>=0.6.18->azure-ai-ml) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.6.0 in /databricks/python3/lib/python3.9/site-packages (from strictyaml<2.0.0->azure-ai-ml) (2.8.2)
# Installing collected packages: azure-storage-blob
#   Attempting uninstall: azure-storage-blob
#     Found existing installation: azure-storage-blob 12.13.0
#     Uninstalling azure-storage-blob-12.13.0:
#       Successfully uninstalled azure-storage-blob-12.13.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# azureml-mlflow 1.49.0 requires azure-storage-blob<=12.13.0,>=12.5.0, but you have azure-storage-blob 12.15.0 which is incompatible.
# Successfully installed azure-storage-blob-12.15.0
# Python interpreter will be restarted.

# %%
import mlflow
import mlflow.azureml
import azureml.mlflow
import azureml.core
from azureml.core import Workspace
from azureml.mlflow import get_portal_url
from mlflow.deployments import get_deploy_client
from azure.identity import DefaultAzureCredential
import os
from azure.ai.ml import MLClient
from azure.ai.ml.entities import Model
from azure.ai.ml.constants import AssetTypes
import datetime
from azure.ai.ml.entities import ManagedOnlineEndpoint, ManagedOnlineDeployment

# %%
model_name = 'test_model'
model_uri = "runs:/d53ec57a17f2482ab298bbd3ee95b484/pyfunc_packaged_model"
try:
    os.mkdir(model_name)
except:
    None


model_path = mlflow.tracking.artifact_utils._download_artifact_from_uri(artifact_uri=model_uri, output_path=model_name)

#dbfs:/databricks/mlflow-tracking/2181675471542338/d53ec57a17f2482ab298bbd3ee95b484/artifacts/pyfunc_packaged_model/MLmodel

# %%
workspace_name = "dbxamlws"
resource_group = "databricks-sandbox-rg"
 
subscription_id = "2a834239-8f89-42e1-8cf1-c3c10090f51c"
tenant_id = "16b3c013-d300-468d-ac64-7eda0820b6d3"

DBX_SP_Client_Secret = dbutils.secrets.get(scope="DBX_SP_Credentials",key="DBX_SP_Client_Secret")
DBX_SP_ClientID = dbutils.secrets.get(scope="DBX_SP_Credentials",key="DBX_SP_ClientID")
DBX_SP_TenantID = dbutils.secrets.get(scope="DBX_SP_Credentials",key="DBX_SP_TenantID")

print(f"Test: {DBX_SP_ClientID}")
print(f"Test: {DBX_SP_Client_Secret}")
print(DBX_SP_TenantID)

os.environ["AZURE_CLIENT_ID"] = DBX_SP_ClientID
os.environ["AZURE_CLIENT_SECRET"] = DBX_SP_Client_Secret
os.environ["AZURE_TENANT_ID"] = DBX_SP_TenantID
# Out:
# Test: [REDACTED]
# Test: [REDACTED]
# [REDACTED]

# %%
print(model_path)


mlflow_model = Model(
    path=model_path,
    type=AssetTypes.MLFLOW_MODEL,
    name=model_name,
    description="Model deployed with V2"
)
# Out:
# /Workspace/Repos/ciaranh@microsoft.com/dstoolkit-mlops-databricks/Data_Scientist/test_model/pyfunc_packaged_model

# %%
#azml_client = MLClient(
#    DefaultAzureCredential(), subscription_id, resource_group, workspace_name
#)

# %%
#azml_client.models.create_or_update(mlflow_model)

# %%
from azureml.core.authentication import ServicePrincipalAuthentication

svc_pr = ServicePrincipalAuthentication(
                        tenant_id="16b3c013-d300-468d-ac64-7eda0820b6d3",
                        service_principal_id= "841ba6d9-a509-44ee-bf40-c0876b4ac6bb",
                        service_principal_password="IQG8Q~hQDGO5eFcRos~YN9waI0gE-Gsx8sMx5bJQ")

ws = Workspace(
         subscription_id=subscription_id,
         resource_group=resource_group,
         workspace_name=workspace_name,
         auth=svc_pr
         )

print(ws)
# Out:
# Workspace.create(name='dbxamlws', subscription_id='2a834239-8f89-42e1-8cf1-c3c10090f51c', resource_group='databricks-sandbox-rg')

# %%
aml_uri = ws.get_mlflow_tracking_uri()
print(aml_uri)
# Out:
# azureml://uksouth.api.azureml.ms/mlflow/v1.0/subscriptions/2a834239-8f89-42e1-8cf1-c3c10090f51c/resourceGroups/databricks-sandbox-rg/providers/Microsoft.MachineLearningServices/workspaces/dbxamlws?

# %%
import mlflow
mlflow.set_tracking_uri(ws.get_mlflow_tracking_uri()) 
print("MLflow tracking URI to point to your Azure ML Workspace setup complete.")
# Out:
# MLflow tracking URI to point to your Azure ML Workspace setup complete.

# %%
experiment_name = 'exp-adb-aml-connection2'
mlflow.set_experiment(experiment_name)
print("Experiment setup complete.")
# Out:
# Experiment setup complete.

# %%
print("Training model...")
output_folder = 'outputs'
model_file_name = 'california-housing.pkl'
dbutils.fs.mkdirs(output_folder)
model_file_path = os.path.join('/dbfs', output_folder, model_file_name)
# Out:
# Training model...

# %%
# %pip install sklearn-pandas==2.1.0
# Out:
# Python interpreter will be restarted.
# Requirement already satisfied: sklearn-pandas==2.1.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-9c30680a-7243-44a5-b665-d717c452c9ec/lib/python3.9/site-packages (2.1.0)
# Requirement already satisfied: pandas>=1.1.4 in /databricks/python3/lib/python3.9/site-packages (from sklearn-pandas==2.1.0) (1.3.4)
# Requirement already satisfied: scikit-learn>=0.23.0 in /databricks/python3/lib/python3.9/site-packages (from sklearn-pandas==2.1.0) (0.24.2)
# Requirement already satisfied: scipy>=1.5.1 in /databricks/python3/lib/python3.9/site-packages (from sklearn-pandas==2.1.0) (1.7.1)
# Requirement already satisfied: numpy>=1.18.1 in /databricks/python3/lib/python3.9/site-packages (from sklearn-pandas==2.1.0) (1.20.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in /databricks/python3/lib/python3.9/site-packages (from pandas>=1.1.4->sklearn-pandas==2.1.0) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /databricks/python3/lib/python3.9/site-packages (from pandas>=1.1.4->sklearn-pandas==2.1.0) (2021.3)
# Requirement already satisfied: six>=1.5 in /databricks/python3/lib/python3.9/site-packages (from python-dateutil>=2.7.3->pandas>=1.1.4->sklearn-pandas==2.1.0) (1.16.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /databricks/python3/lib/python3.9/site-packages (from scikit-learn>=0.23.0->sklearn-pandas==2.1.0) (2.2.0)
# Requirement already satisfied: joblib>=0.11 in /databricks/python3/lib/python3.9/site-packages (from scikit-learn>=0.23.0->sklearn-pandas==2.1.0) (1.0.1)
# Python interpreter will be restarted.

# %%
import pandas as pd
from sklearn.datasets import fetch_california_housing
import os
import numpy as np
import pandas as pd
import pickle
import sklearn
import joblib
import math
import matplotlib
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn_pandas import DataFrameMapper
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

california_housing = fetch_california_housing()
pd_df_california_housing = pd.DataFrame(california_housing.data, columns = california_housing.feature_names) 
pd_df_california_housing['target'] = pd.Series(california_housing.target)

# %%
import mlflow 

mlflow.start_run()  
df = pd_df_california_housing.dropna()  #Drop Missing Values
x_df = df.drop(['target'], axis=1)      #Create Feature Set 
y_df = df['target']                     #Create Label

X_train, X_test, y_train, y_test = train_test_split(x_df, y_df, test_size=0.2, random_state=0) #Train-Test Split

numerical = ['MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'Population', 'AveOccup','Latitude','Longitude']    #List all Numerical Features

numeric_transformations = [([f], Pipeline(steps=[
  ('imputer', SimpleImputer(strategy='median')),                                         #Imputation and Scaling for all numerical variables.
  ('scaler', StandardScaler())])) for f in numerical]                            

transformations = numeric_transformations

clf = Pipeline(steps=[('preprocessor', DataFrameMapper(transformations, df_out=True)),    #Define the pipeline and its steps
                     ('regressor', GradientBoostingRegressor())])

clf.fit(X_train, y_train)                         #Fit the Model

y_predict = clf.predict(X_test)                   #Predict on the test data
y_actual = y_test.values.flatten().tolist()    

rmse = math.sqrt(mean_squared_error(y_actual, y_predict))   #Calculate and log RMSE
mlflow.log_metric('rmse', rmse)
mae = mean_absolute_error(y_actual, y_predict)    #Calculate and log MAE
mlflow.log_metric('mae', mae)
r2 = r2_score(y_actual, y_predict)                #Calculate and log R2 Score
mlflow.log_metric('R2 score', r2)


mlflow.end_run()  

   #results_graph = os.path.join('/dbfs', output_folder, 'results.png') #Log the graph plotted above
   #plt.savefig(results_graph)
   #mlflow.log_artifact(results_graph)

   #joblib.dump(clf, open(model_file_path,'wb'))      #Log the Model
   #mlflow.log_artifact(model_file_path)

# %%
aml_run = list(ws.experiments[experiment_name].get_runs())[0]

# %%
print(aml_run)
# Out:
# Run(Experiment: exp-adb-aml-connection2,
# Id: ecdd0d85-d586-42b9-b5cf-1bf07dc62e2d,
# Type: None,
# Status: Completed)
